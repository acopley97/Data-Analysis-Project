# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Load the Titanic dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
train_data = pd.read_csv('/kaggle/input/titanic2/train.csv')

# Display the first few rows to understand the data
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Calculate survival rate by passenger class
survival_by_class = df.groupby('Pclass')['Survived'].mean() * 100

# Create a bar plot to visualize the survival rate by passenger class
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=survival_by_class.index, y=survival_by_class.values)
plt.title('Survival Rate by Passenger Class on the Titanic', fontsize=16)
plt.xlabel('Passenger Class', fontsize=14)
plt.ylabel('Survival Rate (%)', fontsize=14)
plt.xticks([0, 1, 2], ['1st Class', '2nd Class', '3rd Class'], fontsize=12)

# Add percentage labels on top of each bar
for i, v in enumerate(survival_by_class.values):
    ax.text(i, v + 1, f"{v:.1f}%", ha='center', fontsize=12)

plt.ylim(0, 100)  # Set y-axis limit to 0-100%
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# The data shows that passenger class had a significant impact on survival rates of passengers.
# 1st class passengers had the highest survival rate of 63%.
# 2nd class passengers had the 2nd highest survival rate of 47%.
# 3rd class passengers had the lowest survival rate of 24%.
#
# This could be due to the fact that higher class passengers were prioritized, or because the 1st class passengers were closer to lifeboats than the lower class passengers.

# %%
# Calculate survival rate
survival_rate = df.groupby('Sex')['Survived'].mean().reset_index()

# Plot the survival rate
plt.figure(figsize=(8,6))
plt.bar(survival_rate['Sex'], survival_rate['Survived']*100, color=['skyblue', 'salmon'])
plt.xlabel('Sex')
plt.ylabel('Survival Rate (%)')
plt.title('Titanic Survival Rate based on Sex')
plt.ylim(0, 100)

# Annotate the bars with the survival rate
for index, row in survival_rate.iterrows():
    plt.text(row['Sex'], row['Survived']*100 + 2, f"{row['Survived']*100:.1f}%", ha='center')

plt.show()

# %% [markdown]
# Female passengers had a 74.2% survival rate.
# Male passengers had a 18.9% survival rate.
#
# The data in this graph shows the dramatic difference in survival rates between men and women on the Titanic.
# This data reflects the "women and children first" mentality when it comes to the evacuation process in disasters.
